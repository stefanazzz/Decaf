# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
fname='/data/Dutff0269/20181128_112047_2720_01.atf';
headr=pd.read_csv(fname).iloc[0,0];
head=[he.split("=") for he in headr.split(";")[0:-1] ]
hea=np.array(head)
vals=[float(x) for x in hea[3:,1]]
nams=[x.strip() for x in hea[3:,0]]
for i in range(len(vals)): vars()[nams[i]]=vals[i]

# %%
for i in range(len(vals)): print(nams[i],"=",vars()[nams[i]])
# Out:
# TSamp = 0.2
# TimeUnits = 1e-06
# AmpToVolts = 0.0039063
# TraceMaxVolts = 8.0
# PTime = 0.0
# STime = 0.0

# %%
df=pd.read_csv('/data/Dutff0269/20181128_112047_2720_01.atf',header=2,dtype=float);
dat=np.multiply(df.iloc[:,0].values,AmpToVolts)
tim=[float(i)*TSamp*TimeUnits for i in range(len(dat))]

# %%
# %matplotlib notebook
plt.plot(tim,dat);plt.title(hea[0,1]+" "+hea[1,1]);
# Out:
# <img src="data:image/png;base64,..." width="639.4">
