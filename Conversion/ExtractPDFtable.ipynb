# %%
from tabula import read_pdf
import numpy as np

# %%
df = read_pdf("n6.pdf");df
# Out:
#    Experiment  sn (MPa)   V (m/s)  a (m/s2)  Unnamed: 4  d (m)    mss  \
# 0        s042      40.0       6.5     65.00         NaN  14.93  0.052
# 1        s049      20.0         3     30.00         NaN      6  0.110
# 2        s050      20.0         3     30.00         NaN      6  0.105
# 3        s051      20.0         3      6.00         NaN      6  0.106
# 4        s052      20.0         3      3.00         NaN      6  0.120
# 5        s053      20.0         3      3.00         NaN      6  0.105
# 6        s054      20.0         3      6.00         NaN      6  0.111
# 7        s056      20.0         3     15.00         NaN      6  0.112
# 8        s058      20.0         3     15.00         NaN   7.81  0.101
# 9        s059      20.0         3     15.00         NaN      6  0.103
# 10       s062      40.0         3     30.00         NaN      6  0.075
# 11       s063      40.0         3      3.00         NaN      6  0.073
# 12       s064      10.0         3     30.00         NaN      6  0.147
# 13       s065      10.0         3      3.00         NaN      6  0.175
# 14       s066      20.0         5     30.00         NaN      6  0.103
# 15       s067      20.0       6.5     30.00         NaN      6  0.109
# 16       s070      20.0         1     30.00         NaN     ∼4  0.112
# 17       s071      15.5      1.14      2.85         NaN  15.21  0.145
# 18       s072       1.4  10−3–0.8      5.00         NaN  68.20  0.662
# 19       s073       5.0    10−3–3     30.00         NaN      6  0.258
# 20       s074      10.0         3     30.00         NaN      6  0.145
# 21       s079      15.0         3     30.00         NaN      6  0.126
# 22       s082      20.0         3     60.00         NaN      6  0.106
# 23       s088      20.0         3      2.00         NaN      6  0.105
# 24       s097      30.0         3     30.00         NaN      6  0.089
# 25       s106       5.0         3     30.00         NaN      6  0.265
# 26       s107      30.0         3      3.00         NaN      6  0.092
# 27       s111       2.5         3     30.00         NaN  14.56  0.358
# 28       s113       7.5         3     30.00         NaN   9.14  0.195
# 29       s114      50.0         3     30.00         NaN   0.45  0.071
# 30       s115       1.0         3     30.00         NaN  22.08  0.556
# 31       s117       0.7     3–0.3     30.00         NaN  35.43  0.494
# 32       s129      10.0       1.3      3.25         NaN  10.08  0.098
#
#                             Notes
# 0   deceleration 7.2; no grinding
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16    reached end of axial stroke
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29           40/50; sample failed
# 30                            NaN
# 31                            NaN
# 32                    solid 50 mm

# %%
df.iloc[0,0]
# Out:
# 's042'

# %%
df.iloc[1,0],df.iloc[1,1],float(df.iloc[1,2]),df.iloc[1,6]
# Out:
# ('s049', 20.0, 3.0, 0.11)

# %%
for n in range(1,10):
    print(df.iloc[n,0],df.iloc[n,1],float(df.iloc[n,2]),df.iloc[n,6])
n
# Out:
# s049 20.0 3.0 0.11
# s050 20.0 3.0 0.105
# s051 20.0 3.0 0.106
# s052 20.0 3.0 0.12
# s053 20.0 3.0 0.105
# s054 20.0 3.0 0.111
# s056 20.0 3.0 0.112
# s058 20.0 3.0 0.101
# s059 20.0 3.0 0.103

# %%
mmuss=np.mean([df.iloc[n,6] for n in range(1,10)]); mmuss
# Out:
# 0.1081111111111111

# %%
[df.iloc[n,0] for n in range(1,10)]
# Out:
# ['s049', 's050', 's051', 's052', 's053', 's054', 's056', 's058', 's059']
